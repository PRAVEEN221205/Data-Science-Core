# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Countries.csv')
df.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0        3.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
# ...

# %%
df.shape
# Out:
# (194, 64)

# %%
df.dtypes
# Out:
# country              object
# country_long         object
# currency             object
# capital_city         object
# region               object
#                      ...
# democracy_score     float64
# democracy_type       object
# median_age          float64
# political_leader     object
# title                object
# Length: 64, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    object
#  1   country_long                             194 non-null    object
#  2   currency                                 194 non-null    object
#  3   capital_city                             194 non-null    object
#  4   region                                   194 non-null    object
#  5   continent                                194 non-null    object
#  6   demonym                                  194 non-null    object
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
df.describe()
# Out:
#          latitude   longitude  agricultural_land   forest_area     land_area  \
# count  194.000000  194.000000       1.930000e+02  1.940000e+02  1.940000e+02
# mean    18.975601   22.027491       2.454551e+05  2.086784e+05  6.675087e+05
# std     23.876225   66.396389       6.356268e+05  7.824926e+05  1.837107e+06
# min    -41.000000 -175.000000       4.000000e+00  0.000000e+00  2.027000e+00
# 25%      4.000000   -5.000000       6.464000e+03  3.331775e+03  2.355250e+04
# 50%     16.583333   21.500000       3.872780e+04  2.528925e+04  1.203750e+05
# 75%     40.000000   50.162500       2.150000e+05  1.236735e+05  5.237000e+05
# max     65.000000  178.000000       5.285080e+06  8.153120e+06  1.637690e+07
#
#          rural_land     urban_land  central_government_debt_pct_gdp  \
# count  1.940000e+02     194.000000                       120.000000
# mean   6.563711e+05    9777.116531                        66.759366
# std    1.811169e+06   42301.458421                        71.806247
# ...

# %%
df.isnull().sum()
# Out:
# country             0
# country_long        0
# currency            0
# capital_city        0
# region              0
#                    ..
# democracy_score     0
# democracy_type      0
# median_age          0
# political_leader    7
# title               7
# Length: 64, dtype: int64

# %%
## how many countries doesn't have political_leaders

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# country             0
# country_long        0
# currency            0
# capital_city        0
# region              0
#                    ..
# democracy_score     0
# democracy_type      0
# median_age          0
# political_leader    0
# title               0
# Length: 64, dtype: int64

# %%
df
# Out:
#              country                                country_long  \
# 10        Azerbaijan                      Republic of Azerbaijan
# 12        Bangladesh             People's Republic of Bangladesh
# 19           Bolivia              Plurinational State of Bolivia
# 22            Brazil               Federative Republic of Brazil
# 29          Cameroon                        Republic of Cameroon
# 35          Colombia                        Republic of Colombia
# 37             Congo                           Republic of Congo
# 39     Côte d'Ivoire                   Republic of Côte d'Ivoire
# 40           Croatia                         Republic of Croatia
# 42            Cyprus                          Republic of Cyprus
# 45   Dem. Rep. Congo            Democratic Republic of the Congo
# 52       El Salvador                     Republic of El Salvador
# 57          Ethiopia     Federal Democratic Republic of Ethiopia
# ...

# %%
df.dtypes
# Out:
# country              object
# country_long         object
# currency             object
# capital_city         object
# region               object
#                      ...
# democracy_score     float64
# democracy_type       object
# median_age          float64
# political_leader     object
# title                object
# Length: 64, dtype: object

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'currency', 'capital_city', 'region',
#        'continent', 'demonym', 'latitude', 'longitude', 'agricultural_land',
#        'forest_area', 'land_area', 'rural_land', 'urban_land',
#        'central_government_debt_pct_gdp', 'expense_pct_gdp', 'gdp',
#        'inflation', 'self_employed_pct', 'tax_revenue_pct_gdp',
#        'unemployment_pct', 'vulnerable_employment_pct',
#        'electricity_access_pct', 'alternative_nuclear_energy_pct',
#        'electricty_production_coal_pct',
#        'electricty_production_hydroelectric_pct',
#        'electricty_production_gas_pct', 'electricty_production_nuclear_pct',
#        'electricty_production_oil_pct', 'electricty_production_renewable_pct',
#        'energy_imports_pct', 'fossil_energy_consumption_pct',
#        'renewable_energy_consumption_pct', 'co2_emissions',
#        'methane_emissions', 'nitrous_oxide_emissions',
#        'greenhouse_other_emissions', 'urban_population_under_5m',
# ...

# %%
##country has highest population
df[df['population']==df['population'].max()]['country']
# Out:
# 75    India
# Name: country, dtype: object

# %%
##capital of the country with highest population
df[df['population']==df['population'].max()]['capital_city']
# Out:
# 75    New Delhi
# Name: capital_city, dtype: object

# %%
## capital of the country with least population
df[df['population']==df['population'].min()]['country']
# Out:
# 42    Cyprus
# Name: country, dtype: object

# %%
## to get the five highest country according to there democracy_score
df.nlargest(5,'democracy_score')['country']
# Out:
# 42          Cyprus
# 75           India
# 22          Brazil
# 35        Colombia
# 135    Philippines
# Name: country, dtype: object

# %%
df.sort_values('democracy_score',ascending=False).iloc[0:5]['country']
# Out:
# 42          Cyprus
# 75           India
# 22          Brazil
# 35        Colombia
# 135    Philippines
# Name: country, dtype: object

# %%
## check  how may unique regions are there
df['region'].nunique()
# Out:
# 12

# %%
df['region'].value_counts().count()
# Out:
# np.int64(12)

# %%
## countries lie in eastern europe
df['region'].value_counts()['Eastern Europe']
# Out:
# np.int64(1)

# %%
df[df['region']=='Eastern Europe'].value_counts().sum()
# Out:
# np.int64(1)

# %%
df.loc[df.query("continent=='Africa'")['population'].idxmax()]
# Out:
# country                                            Ethiopia
# country_long        Federal Democratic Republic of Ethiopia
# currency                                     Ethiopian birr
# capital_city                                    Addis Ababa
# region                                       Eastern Africa
#                                      ...
# democracy_score                                        3.35
# democracy_type                                Authoritarian
# median_age                                             14.7
# political_leader                                 Abiy Ahmed
# title                                        Prime Minister
# Name: 57, Length: 64, dtype: object

# %%
## to check which has the country consists of the word republic
def check_republic(txt):
    s=txt.split()
    for i in s:
        if i =='Republic':
            return True
    return False

# %%
df['country_long'].apply(
    check_republic
).sum()
# Out:
# np.int64(23)

# %%
df['country_long'].str.contains('Republic').sum()
# Out:
# np.int64(23)

# %%
df.head()
# Out:
#        country                     country_long                   currency  \
# 10  Azerbaijan           Republic of Azerbaijan            New Azeri manat
# 12  Bangladesh  People's Republic of Bangladesh           Bangladeshi taka
# 19     Bolivia   Plurinational State of Bolivia         Bolivian Boliviano
# 22      Brazil    Federative Republic of Brazil             Brazilian real
# 29    Cameroon             Republic of Cameroon  Central African CFA franc
#
#    capital_city         region continent      demonym  latitude  longitude  \
# 10         Baku   Western Asia      Asia  Azerbaijani      40.5       47.5
# 12        Dhaka  Southern Asia      Asia  Bangladeshi      24.0       90.0
# 19        Sucre  South America  Americas     Bolivian     -17.0      -65.0
# 22     Brasília  South America  Americas    Brazilian     -10.0      -55.0
# 29      Yaoundé  Middle Africa    Africa  Cameroonian       6.0       12.0
#
# ...

# %%
## country in africa has highest population in african region
df.loc[df[df['continent']=='Africa']['population'].idxmax()]
# Out:
# country                                            Ethiopia
# country_long        Federal Democratic Republic of Ethiopia
# currency                                     Ethiopian birr
# capital_city                                    Addis Ababa
# region                                       Eastern Africa
#                                      ...
# democracy_score                                        3.35
# democracy_type                                Authoritarian
# median_age                                             14.7
# political_leader                                 Abiy Ahmed
# title                                        Prime Minister
# Name: 57, Length: 64, dtype: object

# %%
## to get the 2nd highest country political leader
df.nlargest(2, 'population').iloc[-1]['political_leader']
# Out:
# 'Joko Widodo'

# %%
df.sort_values('population',ascending=False).iloc[1]['political_leader']
# Out:
# 'Joko Widodo'
